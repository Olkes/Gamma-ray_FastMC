# %% [markdown]
# ## Test of accelerated Monte Carlo ##

# %%
import sys
sys.path.insert(0, "../python/")

from particle import particle
from physics import em_physics
from cylinder import cylinder
from analysis import analysis 

import matplotlib.pyplot as plt
import numpy as np
#from numba import jit
import pandas as pd

import json
#import uproot
import csv
import time

# %% [markdown]
# ### Define the Geometry ###

# %%
# define the geometry
radius = 65 # cm
height = 150 #cm
cryostat = cylinder(R=radius,h=height)
# cryostat mass of 5869 kg

radius = 57 # cm
height = 134 #cm
fiducial = cylinder(R=radius,h=height)
#fiducial mass of 4032 kg
# Out:
# cylinder::__init__ Define cylinder with R= 65  and height= 150
# cylinder::__init__ Define cylinder with R= 57  and height= 134

# %% [markdown]
# ### Setup the photon physics ###

# %%
# define the physics
em = em_physics()

# %% [markdown]
# ### Event generation ###

# %%
def event_generator(n,energy,emax,mode,nscatter,seed):
    #
    #random seed
    np.random.seed(seed)
    #
    #
    # number of events
    #
    nevent = n
    #
    # gamma energy
    #
    energy = energy # keV
    #
    #
    #number of scaters that are writen to file
    #
    writeout = 4 #scatter events
    #
    #
    
    # event generation loop
    #
    #
    
    tarr=[]
    
    for ieve in range(nevent):

        if ieve%25000 == 0:
            print("generated ",ieve," events")
        #
        # make a particle,
        #
        vrt = mode#'fiducial_scatter'
        
        p = particle(type='gamma',
                     energy=energy, 
                     geometry=cryostat, 
                     fiducial=fiducial, 
                     vrt=vrt, 
                     edep_max=emax,
                     nscatter_max=nscatter,
                     physics=em,
                     debug=False,
                    )

        #
        # propagate the particle and retrieve the intersection points
        #
        p.propagate()

        #
        # store data
        #            
        warr = [ieve,len(p.xint),p.weight,p.edep,p.x0start[0],p.x0start[1],p.x0start[2]]
        
        for i in range(len(p.xint)):    
            warr.extend([p.xint[i][0][0],p.xint[i][0][1],p.xint[i][0][2],p.xint[i][1]])                        
        
        tarr.append(warr[:((writeout*4)+7)])
        
    #
    # close output data file
    #
    df= pd.DataFrame(tarr)
    
    
    if vrt == 'fiducial_scatter':
        
        df.to_csv('../mcdata/testdata_events'+ str(n)+'_mode:vrt'+'_nscatters' +str(nscatter)+'_edep' +str(energy)+ '.' +'csv', index=False, header=False)

    else:
        df.to_csv('../mcdata/testdata_events'+ str(n)+'_mode:nonvrt'+'_nscatters' +str(nscatter)+'_edep' +str(energy)+ '.' +'csv', index=False, header=False)
    


    #print(df)

# %%
event_generator(n=1000000,energy=1500,emax=250,mode='fiducial_scatter',nscatter=1,seed=42)
event_generator(n=1000000,energy=1500,emax=250,mode='fiducial_scatter',nscatter=2,seed=43)
event_generator(n=1000000,energy=1500,emax=2500,mode=None,nscatter=2,seed=44)
# Out:
# generated  0  events
# generated  25000  events
# generated  50000  events
# generated  75000  events
# generated  100000  events
# generated  125000  events
# generated  150000  events
# generated  175000  events
# generated  200000  events
# generated  225000  events
# generated  250000  events
# generated  275000  events
# generated  300000  events
# generated  325000  events
# generated  350000  events
# generated  375000  events
# generated  400000  events
# generated  425000  events
# generated  450000  events
# generated  475000  events
# generated  500000  events
# generated  525000  events
# generated  550000  events
# generated  575000  events
# generated  600000  events
# generated  625000  events
# generated  650000  events
# generated  675000  events
# generated  700000  events
# generated  725000  events
# generated  750000  events
# generated  775000  events
# generated  800000  events
# generated  825000  events
# generated  850000  events
# generated  875000  events
# generated  900000  events
# generated  925000  events
# generated  950000  events
# generated  975000  events
# generated  0  events
# generated  25000  events
# generated  50000  events
# generated  75000  events
# generated  100000  events
# generated  125000  events
# generated  150000  events
# generated  175000  events
# generated  200000  events
# generated  225000  events
# generated  250000  events
# generated  275000  events
# generated  300000  events
# generated  325000  events
# generated  350000  events
# generated  375000  events
# generated  400000  events
# generated  425000  events
# generated  450000  events
# generated  475000  events
# generated  500000  events
# generated  525000  events
# generated  550000  events
# generated  575000  events
# generated  600000  events
# generated  625000  events
# generated  650000  events
# generated  675000  events
# generated  700000  events
# generated  725000  events
# generated  750000  events
# generated  775000  events
# generated  800000  events
# generated  825000  events
# generated  850000  events
# generated  875000  events
# generated  900000  events
# generated  925000  events
# generated  950000  events
# generated  975000  events

# %% [markdown]
# ## Make reference simulation##

# %% [markdown]
# This is basically the same as the normal simulation; only this saves the values every x steps to prevent memory loss. (Value is a tradeoff between memory and computation time.)

# %%
def ref_event_generator(n=10000000,energy=10000,emax=250,mode='fiducial_scatter',nscatter=1,seed=42):

    #%%prun -D my.profile
    #
    #random seed
    np.random.seed(seed)
    #
    # number of events
    #
    nevent = n
    #
    # gamma energy
    #
    energy = energy # keV
    #
    #
    #number of scaters that are writen to file
    #
    writeout = 4 #scatter events
    #
    #
    
    # event generation loop
    #
    #
    
    tarr=[]
    file = '../mcdata/reference'+str(n)+'.' +'csv'
    open(file, 'w').close()
    
    for ieve in range(nevent):

        if ieve%25000 == 0:
            print("generated ",ieve," events")
        #
        # make a particle,
        #
        seed = None
        vrt = mode #'fiducial_scatter'
        if vrt==None: nscatter = 20
        
        p = particle(type='gamma',
                     energy=energy, 
                     geometry=cryostat, 
                     fiducial=fiducial, 
                     vrt=vrt, 
                     edep_max=emax,
                     nscatter_max=nscatter,
                     physics=em,
                     debug=False,
                     seed=seed #ieve*42 random seed for testing None for not giving a seed
                    )

        #
        # propagate the particle and retrieve the intersection points
        #
        p.propagate()

        #
        # store data
        #            
        warr = [ieve,len(p.xint),p.weight,p.edep,p.x0start[0],p.x0start[1],p.x0start[2]]
        
        
        for i in range(len(p.xint)):    
            warr.extend([p.xint[i][0][0],p.xint[i][0][1],p.xint[i][0][2],p.xint[i][1]])
            
        
        
        tarr.append(warr[:((writeout*4)+7)])
        
        # Write every x event to file
        if ieve%25000 == 0:
            df= pd.DataFrame(tarr)
            df.to_csv(file,mode='a',index=False, header=False)
            tarr=[]
            del(df)

    #print(df)
    return

# generated  8275000  events
# generated  8300000  events
# generated  8325000  events
# generated  8350000  events
# generated  8375000  events
# generated  8400000  events
# generated  8425000  events
# generated  8450000  events
# generated  8475000  events
# generated  8500000  events
# generated  8525000  events
# generated  8550000  events
# generated  8575000  events
# generated  8600000  events
# generated  8625000  events
# generated  8650000  events
# generated  8675000  events
# generated  8700000  events
# generated  8725000  events
# generated  8750000  events
# generated  8775000  events
# generated  8800000  events
# generated  8825000  events
# generated  8850000  events
# generated  8875000  events
# generated  8900000  events
# generated  8925000  events
# generated  8950000  events
# generated  8975000  events
# generated  9000000  events
# generated  9025000  events
# generated  9050000  events
# generated  9075000  events
# generated  9100000  events
# generated  9125000  events
# generated  9150000  events
# generated  9175000  events
# generated  9200000  events
# generated  9225000  events
# generated  9250000  events
# generated  9275000  events
# generated  9300000  events
# generated  9325000  events
# generated  9350000  events
# generated  9375000  events
# generated  9400000  events
# generated  9425000  events
# generated  9450000  events
# generated  9475000  events
# generated  9500000  events
# generated  9525000  events
# generated  9550000  events
# generated  9575000  events
# generated  9600000  events
# generated  9625000  events
# generated  9650000  events
# generated  9675000  events
# generated  9700000  events
# generated  9725000  events
# generated  9750000  events
# generated  9775000  events
# generated  9800000  events
# generated  9825000  events
# generated  9850000  events
# generated  9875000  events
# generated  9900000  events
# generated  9925000  events
# generated  9950000  events
# generated  9975000  events
# generated  10000000  events

# %%
# Out:
# generated  0  events
# generated  25000  events
# generated  50000  events
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ba19284111a7> in <module>()
# ----> 1 ref_event_generator(n=100000)
#
# <ipython-input-4-063ffdb91053> in ref_event_generator(n, energy, emax, mode, nscatter, seed)
#      55         # propagate the particle and retrieve the intersection points
#      56         #
# ---> 57         p.propagate()
#      58
#      59         #
#
# ~/FastMC/python/particle.py in propagate(self)
#     306                     # actual scattering: either Compton or Photo-electric effect
#     307                     #
# --> 308                     process = self.scatter(s_gen)
#     309                     #
#     310                     # if the scattering was by the Photo-electric effect, the photon is terminated
#
# ~/FastMC/python/particle.py in scatter(self, s)
#     373             # Compton scatter
#     374             #
# --> 375             theta_s, phi_s, w_s = self.phys.do_compton(self.energy, self.edep_max)
#     376             self.update_particle('inc',s,theta_s, phi_s, w_s)
#     377
#
# ~/FastMC/python/physics.py in do_compton(self, energy, de_max)
#     256         # make the cdf from the differential cross section
#     257         #
# --> 258         cost_range = np.linspace(-1.0, +1.0, 10001, endpoint=True)
#     259         dsigma = self.KleinNishina(energy, cost_range, formfactor=True)
#     260         cdf = dsigma.cumsum() / dsigma.sum()
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /data/xenon/olivier/venvs/nb_venv/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     130     stop  = asanyarray(stop)  * 1.0
#     131
# --> 132     dt = result_type(start, stop, float(num))
#     133     if dtype is None:
#     134         dtype = dt
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# KeyboardInterrupt:
